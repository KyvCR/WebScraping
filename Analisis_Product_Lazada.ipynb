# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### data from scraping webiste lazada, Katagori --> Peralatan Elektronik --> Handphone

# %%
df = pd.read_excel('Product_lazada_get_api.xlsx')
df.head(10)
# Out:
#               Seller     Brand
# 0               vivo      Vivo  \
# 1               vivo      Vivo
# 2    vinz flash sale      itel
# 3  Top 1 smart phone  No Brand
# 4      Original Link   Infinix
# 5  Top 1 smart phone  No Brand
# 6             36Shop      itel
# 7            BB Shop      itel
# 8       Mentari Cell    Xiaomi
# 9      Duniagadgetku      itel
#
#                                                 Name    Price
# 0  vivo iQOO Z7 (8/128) - SDM 782G, 120W FlashCha...  4299000  \
# 1  vivo iQOO Z7 (12/256) - SDM 782G, 120W FlashCh...  4899000
# 2                        Itel P40 4/64 GARANSI RESMI  1098900
# 3  【Beli 1 Gratis 1】Produk hp Murah asli A57 7.5I...   899999
# 4  Infinix Hot 30i 8/128 GB RAM 8 ROM 128 8GB 128...  1799000
# 5  【FLASH SALE】 hp murah Reno9 Pro 5G 7.5Inci Pon...  1100000
# 6  Itel P40 4GB+64GB Garansi Resmi, LAYAR Jenis I...  1299000
# 7  Itel P40 4GB+64GB Garansi Resmi, LAYAR Jenis I...  1299000
# 8  XIAOMI REDMI NOTE 8 - 3GB/32GB - Chipset    Qu...  1342569
# 9            ITEL P40 RAM (4GB/64GB) - GARANSI RESMI  1150000
#
#              Location                                               Link
# 0      Kab. Tangerang  //www.lazada.co.id/products/vivo-iqoo-z7-8128-...
# 1      Kab. Tangerang  //www.lazada.co.id/products/vivo-iqoo-z7-12256...
# 2  Kota Jakarta Utara  //www.lazada.co.id/products/itel-p40-464-garan...
# 3  Kota Jakarta Utara  //www.lazada.co.id/products/beli-1-gratis-1pro...
# 4  Kota Jakarta Utara  //www.lazada.co.id/products/infinix-hot-30i-81...
# 5  Kota Jakarta Utara  //www.lazada.co.id/products/flash-sale-hp-mura...
# 6  Kota Jakarta Barat  //www.lazada.co.id/products/itel-p40-4gb64gb-g...
# 7  Kota Jakarta Barat  //www.lazada.co.id/products/itel-p40-4gb64gb-g...
# 8         Kab. Madiun  //www.lazada.co.id/products/xiaomi-redmi-note-...
# 9  Kota Jakarta Barat  //www.lazada.co.id/products/itel-p40-ram-4gb64...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Seller    200 non-null    object
#  1   Brand     200 non-null    object
#  2   Name      200 non-null    object
#  3   Price     200 non-null    int64
#  4   Location  200 non-null    object
#  5   Link      200 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 9.5+ KB

# %% [markdown]
# ### Cleaning Data

# %%
df_clean = df[(df['Seller'] == 'Smart Phone Sale') | (df['Seller'] == 'Top 1 smart phone')]
df_clean
# Out:
#                 Seller     Brand
# 3    Top 1 smart phone  No Brand  \
# 5    Top 1 smart phone  No Brand
# 43   Top 1 smart phone  No Brand
# 45   Top 1 smart phone  No Brand
# 96    Smart Phone Sale  No Brand
# 103   Smart Phone Sale  No Brand
# 123  Top 1 smart phone  No Brand
# 125  Top 1 smart phone  No Brand
# 171   Smart Phone Sale  No Brand
# 176   Smart Phone Sale  No Brand
#
#                                                   Name    Price
# 3    【Beli 1 Gratis 1】Produk hp Murah asli A57 7.5I...   899999  \
# 5    【FLASH SALE】 hp murah Reno9 Pro 5G 7.5Inci Pon...  1100000
# 43   【Beli 1 Gratis 1】Produk hp Murah asli A57 7.5I...   899999
# 45   【FLASH SALE】 hp murah Reno9 Pro 5G 7.5Inci Pon...  1100000
# 96   【Beli 1 Gratis 6】HP Murah Galaxy S23 Ultra+ 5G...  1100000
# 103  【Beli 1 Gratis 6】 hp murah Reno8Z Pro 5G 7.5In...  1100000
# 123  【Beli 1 Gratis 1】Produk hp Murah asli A57 7.5I...   899999
# 125  【FLASH SALE】 hp murah Reno9 Pro 5G 7.5Inci Pon...  1100000
# 171  【Beli 1 Gratis 6】HP Murah Galaxy S23 Ultra+ 5G...  1100000
# 176  【Beli 1 Gratis 6】 hp murah Reno8Z Pro 5G 7.5In...  1100000
#
#                Location                                               Link
# 3    Kota Jakarta Utara  //www.lazada.co.id/products/beli-1-gratis-1pro...
# 5    Kota Jakarta Utara  //www.lazada.co.id/products/flash-sale-hp-mura...
# 43   Kota Jakarta Utara  //www.lazada.co.id/products/beli-1-gratis-1pro...
# 45   Kota Jakarta Utara  //www.lazada.co.id/products/flash-sale-hp-mura...
# 96   Kota Jakarta Utara  //www.lazada.co.id/products/beli-1-gratis-6hp-...
# 103  Kota Jakarta Utara  //www.lazada.co.id/products/beli-1-gratis-6-hp...
# 123  Kota Jakarta Utara  //www.lazada.co.id/products/beli-1-gratis-1pro...
# 125  Kota Jakarta Utara  //www.lazada.co.id/products/flash-sale-hp-mura...
# 171  Kota Jakarta Utara  //www.lazada.co.id/products/beli-1-gratis-6hp-...
# 176  Kota Jakarta Utara  //www.lazada.co.id/products/beli-1-gratis-6-hp...

# %% [markdown]
# ##### Karena kita sudah dapat data dari kolom 'Name' yang kurang jelas maka kita tidak akan menampilkan data tersebut pada

# %%
df = df[(df['Seller'] != 'Smart Phone Sale') & (df['Seller'] != 'Top 1 smart phone')].reset_index(drop=True)
df
# Out:
#                       Seller    Brand
# 0                       vivo     Vivo  \
# 1                       vivo     Vivo
# 2            vinz flash sale     itel
# 3              Original Link  Infinix
# 4                     36Shop     itel
# ..                       ...      ...
# 185  Murahmeriah shop online   Realme
# 186  Murahmeriah shop online  Samsung
# 187  Murahmeriah shop online  Infinix
# 188  Murahmeriah shop online  Samsung
# 189  Murahmeriah shop online  Samsung
#
#                                                   Name    Price
# 0    vivo iQOO Z7 (8/128) - SDM 782G, 120W FlashCha...  4299000  \
# 1    vivo iQOO Z7 (12/256) - SDM 782G, 120W FlashCh...  4899000
# 2                          Itel P40 4/64 GARANSI RESMI  1098900
# 3    Infinix Hot 30i 8/128 GB RAM 8 ROM 128 8GB 128...  1799000
# 4    Itel P40 4GB+64GB Garansi Resmi, LAYAR Jenis I...  1299000
# ..                                                 ...      ...
# 185         Realme C55 ( 6/128 - 8/256 ) Garansi Resmi  2344000
# 186  Samsung Galaxy A54 ( 8/128 + 8/256 ) Garansi R...  5738000
# 187              Infinix Hot 20s (8/128) Garansi Resmi  2388000
# 188  Samsung Galaxy A34 ( 8/128 + 8/256 ) Garansi R...  4569000
# 189  Samsung Galaxy a14 Lte/4G ( 4/128 / 6/128 ) Ga...  2208000
#
#                  Location                                               Link
# 0          Kab. Tangerang  //www.lazada.co.id/products/vivo-iqoo-z7-8128-...
# 1          Kab. Tangerang  //www.lazada.co.id/products/vivo-iqoo-z7-12256...
# 2      Kota Jakarta Utara  //www.lazada.co.id/products/itel-p40-464-garan...
# 3      Kota Jakarta Utara  //www.lazada.co.id/products/infinix-hot-30i-81...
# 4      Kota Jakarta Barat  //www.lazada.co.id/products/itel-p40-4gb64gb-g...
# ..                    ...                                                ...
# 185  Kota Jakarta Selatan  //www.lazada.co.id/products/realme-c55-6128-82...
# 186  Kota Jakarta Selatan  //www.lazada.co.id/products/samsung-galaxy-a54...
# 187  Kota Jakarta Selatan  //www.lazada.co.id/products/infinix-hot-20s-81...
# 188  Kota Jakarta Selatan  //www.lazada.co.id/products/samsung-galaxy-a34...
# 189  Kota Jakarta Selatan  //www.lazada.co.id/products/samsung-galaxy-a14...
#
# [190 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Seller    190 non-null    object
#  1   Brand     190 non-null    object
#  2   Name      190 non-null    object
#  3   Price     190 non-null    int64
#  4   Location  190 non-null    object
#  5   Link      190 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 9.0+ KB

# %% [markdown]
# ##### membersihkan data yang terdapat pada kolom 'Name'

# %%
df_cleaning_name = df['Name']
tanda = ['(', ')', '<', '>', '[', ']', '-', '+', '【', '】', ',']
for t in tanda:
    df_cleaning_name = df_cleaning_name.str.replace(t, '')

df_cleaning_name
# Out:
# 0      vivo iQOO Z7 8/128  SDM 782G 120W FlashCharge ...
# 1      vivo iQOO Z7 12/256  SDM 782G 120W FlashCharge...
# 2                            Itel P40 4/64 GARANSI RESMI
# 3      Infinix Hot 30i 8/128 GB RAM 8 ROM 128 8GB 128...
# 4      Itel P40 4GB64GB Garansi Resmi LAYAR Jenis IPS...
#                              ...
# 185              Realme C55  6/128  8/256  Garansi Resmi
# 186    Samsung Galaxy A54  8/128  8/256  Garansi Resm...
# 187                  Infinix Hot 20s 8/128 Garansi Resmi
# 188    Samsung Galaxy A34  8/128  8/256  Garansi Resm...
# 189    Samsung Galaxy a14 Lte/4G  4/128 / 6/128  Gara...
# Name: Name, Length: 190, dtype: object

# %% [markdown]
# ##### Melakukan split Kolom 'Name' untuk mengambil beberapa data saja untuk di tampilkan

# %%
df_split_name = df_cleaning_name.str.split(expand=True)
df_split_name.head(20)
# Out:
#          0      1        2         3         4           5         6
# 0      vivo   iQOO       Z7     8/128       SDM        782G      120W  \
# 1      vivo   iQOO       Z7    12/256       SDM        782G      120W
# 2      Itel    P40     4/64   GARANSI     RESMI        None      None
# 3   Infinix    Hot      30i     8/128        GB         RAM         8
# 4      Itel    P40  4GB64GB   Garansi     Resmi       LAYAR     Jenis
# 5      Itel    P40  4GB64GB   Garansi     Resmi       LAYAR     Jenis
# 6    XIAOMI  REDMI     NOTE         8  3GB/32GB     Chipset  Qualcomm
# 7      ITEL    P40      RAM  4GB/64GB   GARANSI       RESMI      None
# 8    Realme    C55  6/128GB   Garansi     Resmi   Indonesia      None
# 9   Infinix  Smart        7   3GB64GB   4GB64GB     Garansi     Resmi
# 10  Infinix  Smart        7      4/64   Garansi       Resmi      None
# 11     itel    P40    43/64   Garansi     Resmi        None      None
# 12    Tecno  spark       10  44/128gb   Garansi       Resmi      None
# 13    Tecno  Spark       10       Pro   8/256GB     Garansi     Resmi
# 14    Tecno   POVA      Neo         2   4/128GB        None      None
# 15    Tecno  Spark       Go      2023      4/64        None      None
# 16     BARU   OPPO     RENO        8T         |    8GB256GB         |
# 17     BARU   OPPO     RENO        8Z        5G           |       RAM
# 18  IIIF150   Air1    Ultra      24GB     256GB  Smartphone   Tangguh
# 19   XIAOMI  REDMI     NOTE        12       RAM       6/128        GB
#
#              7           8       9   ...      22      23         24       25
# 0   FlashCharge     5000mAh    64MP  ...    None    None       None     None  \
# 1   FlashCharge     5000mAh    64MP  ...    None    None       None     None
# 2          None        None    None  ...    None    None       None     None
# 3           ROM         128     8GB  ...    None    None       None     None
# 4           IPS         LCD  Ukuran  ...   Jenis    LiPo  Kapasitas     6000
# 5           IPS         LCD  Ukuran  ...   Jenis    LiPo  Kapasitas     6000
# 6        SDM665  Snapdragon     665  ...    None    None       None     None
# 7          None        None    None  ...    None    None       None     None
# 8          None        None    None  ...    None    None       None     None
# 9       Infinix           1   Tahun  ...  camera  Single        5MP  Battery
# 10         None        None    None  ...    None    None       None     None
# 11         None        None    None  ...    None    None       None     None
# 12         None        None    None  ...    None    None       None     None
# 13         None        None    None  ...    None    None       None     None
# 14         None        None    None  ...    None    None       None     None
# 15         None        None    None  ...    None    None       None     None
# 16           OS     Android      13  ...    None    None       None     None
# 17          8GB           /     ROM  ...    None    None       None     None
# 18        Helio         G99    64MP  ...    None    None       None     None
# 19      GARANSI       RESMI     TAM  ...    None    None       None     None
#
#       26    27    28    29            30    31
# 0   None  None  None  None          None  None
# 1   None  None  None  None          None  None
# 2   None  None  None  None          None  None
# 3   None  None  None  None          None  None
# 4    mAh  None  None  None          None  None
# 5    mAh  None  None  None          None  None
# 6   None  None  None  None          None  None
# 7   None  None  None  None          None  None
# 8   None  None  None  None          None  None
# 9   Type  LiPo  5000   mAh  nonremovable  None
# 10  None  None  None  None          None  None
# 11  None  None  None  None          None  None
# 12  None  None  None  None          None  None
# 13  None  None  None  None          None  None
# 14  None  None  None  None          None  None
# 15  None  None  None  None          None  None
# 16  None  None  None  None          None  None
# 17  None  None  None  None          None  None
# 18  None  None  None  None          None  None
# 19  None  None  None  None          None  None
#
# [20 rows x 32 columns]

# %% [markdown]
# ##### mengambil beberapa index dari kolom yang sudah di split

# %%
product_name = []
for index, row in df_split_name.iterrows():
    data = row[0]
    data1 = row[1]
    data2 = row[2]
    data3 = row[3] 
    if data3 == 'GARANSI' or data3 == 'Garansi' or data3 == 'garansi':
        data_concat = f'{data} {data1} {data2}'
        data_df = pd.DataFrame({'Product_Name' : [data_concat]})
        product_name.append(data_df)
    else:
        data_concat = f'{data} {data1} {data2} {data3}'
        data_df = pd.DataFrame({'Product_Name' : [data_concat]})
        product_name.append(data_df)

pd_concat = pd.concat(product_name).reset_index(drop=True)
pd_concat.head(20)
# Out:
#                Product_Name
# 0        vivo iQOO Z7 8/128
# 1       vivo iQOO Z7 12/256
# 2             Itel P40 4/64
# 3     Infinix Hot 30i 8/128
# 4          Itel P40 4GB64GB
# 5          Itel P40 4GB64GB
# 6       XIAOMI REDMI NOTE 8
# 7     ITEL P40 RAM 4GB/64GB
# 8        Realme C55 6/128GB
# 9   Infinix Smart 7 3GB64GB
# 10     Infinix Smart 7 4/64
# 11           itel P40 43/64
# 12  Tecno spark 10 44/128gb
# 13       Tecno Spark 10 Pro
# 14         Tecno POVA Neo 2
# 15      Tecno Spark Go 2023
# 16        BARU OPPO RENO 8T
# 17        BARU OPPO RENO 8Z
# 18  IIIF150 Air1 Ultra 24GB
# 19     XIAOMI REDMI NOTE 12

# %%
df['Product_Name'] = pd_concat
df.head(20)
# Out:
#                     Seller     Brand
# 0                     vivo      Vivo  \
# 1                     vivo      Vivo
# 2          vinz flash sale      itel
# 3            Original Link   Infinix
# 4                   36Shop      itel
# 5                  BB Shop      itel
# 6             Mentari Cell    Xiaomi
# 7            Duniagadgetku      itel
# 8      Apollo Gadget Store    Realme
# 9                   36Shop   Infinix
# 10           Bandarhpmurah   Infinix
# 11        Galeri-Hp 040595  No Brand
# 12        Galeri-Hp 040595  No Brand
# 13         GALERI NASIONAL  No Brand
# 14                  EVOGAD      Vivo
# 15                  EVOGAD   Samsung
# 16            Mentari Cell      OPPO
# 17            Mentari Cell      OPPO
# 18  OUKITEL Flagship Store   OUKITEL
# 19           Pasar Ponsel     Xiaomi
#
#                                                  Name    Price
# 0   vivo iQOO Z7 (8/128) - SDM 782G, 120W FlashCha...  4299000  \
# 1   vivo iQOO Z7 (12/256) - SDM 782G, 120W FlashCh...  4899000
# 2                         Itel P40 4/64 GARANSI RESMI  1098900
# 3   Infinix Hot 30i 8/128 GB RAM 8 ROM 128 8GB 128...  1799000
# 4   Itel P40 4GB+64GB Garansi Resmi, LAYAR Jenis I...  1299000
# 5   Itel P40 4GB+64GB Garansi Resmi, LAYAR Jenis I...  1299000
# 6   XIAOMI REDMI NOTE 8 - 3GB/32GB - Chipset    Qu...  1342569
# 7             ITEL P40 RAM (4GB/64GB) - GARANSI RESMI  1150000
# 8          Realme C55 6/128GB Garansi Resmi Indonesia  2499000
# 9   Infinix Smart 7 [3GB+64GB] [4GB+64GB] Garansi ...  1209000
# 10               Infinix Smart 7 4/64 - Garansi Resmi  1210000
# 11                      itel P40 4+3/64 Garansi Resmi  1199000
# 12             Tecno spark 10 4+4/128gb Garansi Resmi  1698000
# 13           Tecno Spark 10 Pro 8/256GB Garansi Resmi  2498000
# 14                          Tecno POVA Neo 2, 4/128GB  1816000
# 15                           Tecno Spark Go 2023 4/64  1266000
# 16  [BARU] OPPO RENO 8T | 8GB+256GB | OS Android 1...  4137069
# 17  [BARU] OPPO RENO 8Z 5G | RAM 8GB / ROM 256GB |...  4447569
# 18  IIIF150 Air1 Ultra+ 24GB 256GB Smartphone Tang...  4847507
# 19  XIAOMI REDMI NOTE 12 RAM 6/128 GB GARANSI RESM...  2693200
#
#               Location                                               Link
# 0       Kab. Tangerang  //www.lazada.co.id/products/vivo-iqoo-z7-8128-...  \
# 1       Kab. Tangerang  //www.lazada.co.id/products/vivo-iqoo-z7-12256...
# 2   Kota Jakarta Utara  //www.lazada.co.id/products/itel-p40-464-garan...
# 3   Kota Jakarta Utara  //www.lazada.co.id/products/infinix-hot-30i-81...
# 4   Kota Jakarta Barat  //www.lazada.co.id/products/itel-p40-4gb64gb-g...
# 5   Kota Jakarta Barat  //www.lazada.co.id/products/itel-p40-4gb64gb-g...
# 6          Kab. Madiun  //www.lazada.co.id/products/xiaomi-redmi-note-...
# 7   Kota Jakarta Barat  //www.lazada.co.id/products/itel-p40-ram-4gb64...
# 8        Kota Surabaya  //www.lazada.co.id/products/realme-c55-6128gb-...
# 9   Kota Jakarta Barat  //www.lazada.co.id/products/infinix-smart-7-3g...
# 10  Kota Jakarta Utara  //www.lazada.co.id/products/infinix-smart-7-46...
# 11  Kota Jakarta Pusat  //www.lazada.co.id/products/itel-p40-4364-gara...
# 12  Kota Jakarta Pusat  //www.lazada.co.id/products/tecno-spark-10-441...
# 13  Kota Jakarta Pusat  //www.lazada.co.id/products/tecno-spark-10-pro...
# 14  Kota Jakarta Barat  //www.lazada.co.id/products/tecno-pova-neo-2-4...
# 15  Kota Jakarta Barat  //www.lazada.co.id/products/tecno-spark-go-202...
# 16         Kab. Madiun  //www.lazada.co.id/products/baru-oppo-reno-8t-...
# 17         Kab. Madiun  //www.lazada.co.id/products/baru-oppo-reno-8z-...
# 18         Luar Negeri  //www.lazada.co.id/products/iiif150-air1-ultra...
# 19       Kota Surabaya  //www.lazada.co.id/products/xiaomi-redmi-note-...
#
#                Product_Name
# 0        vivo iQOO Z7 8/128
# 1       vivo iQOO Z7 12/256
# 2             Itel P40 4/64
# 3     Infinix Hot 30i 8/128
# 4          Itel P40 4GB64GB
# 5          Itel P40 4GB64GB
# 6       XIAOMI REDMI NOTE 8
# 7     ITEL P40 RAM 4GB/64GB
# 8        Realme C55 6/128GB
# 9   Infinix Smart 7 3GB64GB
# 10     Infinix Smart 7 4/64
# 11           itel P40 43/64
# 12  Tecno spark 10 44/128gb
# 13       Tecno Spark 10 Pro
# 14         Tecno POVA Neo 2
# 15      Tecno Spark Go 2023
# 16        BARU OPPO RENO 8T
# 17        BARU OPPO RENO 8Z
# 18  IIIF150 Air1 Ultra 24GB
# 19     XIAOMI REDMI NOTE 12

# %% [markdown]
# ### Brand HP yang banyak dijual di lazada

# %%
df_seller = df[['Seller', 'Brand']].groupby(by=['Brand']).count().reset_index()

# %%
plt.bar(df_seller['Brand'], df_seller['Seller'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Kota yang banyak penjual product HP

# %%
df_location = df[['Seller', 'Location']].groupby(by=['Location']).count().reset_index().sort_values("Seller",ascending=True)
df_location
# Out:
#                 Location  Seller
# 0            Kab. Bekasi       1
# 10           Kota Madiun       1
# 12      Kota Tasikmalaya       1
# 9            Kota Kediri       6
# 4             Kota Depok       7
# 2         Kab. Tangerang      10
# 3           Kota Bandung      12
# 13           Luar Negeri      13
# 6     Kota Jakarta Pusat      18
# 11         Kota Surabaya      18
# 8     Kota Jakarta Utara      19
# 1            Kab. Madiun      24
# 5     Kota Jakarta Barat      28
# 7   Kota Jakarta Selatan      32

# %%
plt.barh(df_location['Location'], df_location['Seller'])
plt.show()

# %%
df_seller = df[['Seller', 'Brand', 'Name']].groupby(by=['Seller', 'Brand']).size().reset_index(name='count').sort_values("Seller",ascending=True)
df_seller.head(10)
# Out:
#                  Seller    Brand  count
# 0                36Shop  Infinix      3
# 1                36Shop     itel      3
# 2   Apollo Gadget Store   Realme      1
# 3             Aurora888    Redmi      2
# 4             Aurora888     Vivo      2
# 5               BB Shop   Xiaomi      3
# 6               BB Shop     itel      3
# 7         Bandarhpmurah  Infinix      3
# 8  Captain Gadget Store     OPPO      1
# 9        Cv.Garden Cell   Xiaomi      6

# %% [markdown]
# ### Maximum, Minimum, and Average Prices

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
price_avg = df[['Brand','Price']].groupby(by=['Brand']).mean()
price_avg
# Out:
#                Price
# Brand
# Infinix  1526690.233
# No Brand 1171818.182
# Nokia    1324000.000
# OPPO     3155465.529
# OUKITEL  4847507.000
# Realme   2526633.333
# Redmi     980000.000
# Samsung  3345063.133
# Tecno    2476750.000
# Vivo     3201925.520
# Xiaomi   2459427.375
# berjemur 1075000.000
# itel     1211725.000

# %%
price_max = df[['Brand','Price']].groupby(by=['Brand']).max()
price_max
# Out:
#             Price
# Brand
# Infinix   3469000
# No Brand  2639000
# Nokia     1324000
# OPPO      5990000
# OUKITEL   4847507
# Realme    2998000
# Redmi      980000
# Samsung   6088000
# Tecno     2989000
# Vivo      5730000
# Xiaomi    4599000
# berjemur  1075000
# itel      1299000

# %%
price_min = df[['Brand','Price']].groupby(by=['Brand']).min()
price_min
# Out:
#             Price
# Brand
# Infinix   1175000
# No Brand   155000
# Nokia     1324000
# OPPO      1095000
# OUKITEL   4847507
# Realme    1999000
# Redmi      980000
# Samsung   1266000
# Tecno     1298000
# Vivo       519000
# Xiaomi    1032069
# berjemur  1075000
# itel      1098900

# %%
all_price = pd.merge(pd.merge(price_max, price_min, on='Brand'), price_avg, on='Brand')
new_name_kolom = {'Price_x' : 'Price_max', 'Price_y' : 'Price_min', 'Price' : 'Price_avg'}
all_price = all_price.rename(columns=new_name_kolom).reset_index()
all_price
# Out:
#        Brand  Price_max  Price_min   Price_avg
# 0    Infinix    3469000    1175000 1526690.233
# 1   No Brand    2639000     155000 1171818.182
# 2      Nokia    1324000    1324000 1324000.000
# 3       OPPO    5990000    1095000 3155465.529
# 4    OUKITEL    4847507    4847507 4847507.000
# 5     Realme    2998000    1999000 2526633.333
# 6      Redmi     980000     980000  980000.000
# 7    Samsung    6088000    1266000 3345063.133
# 8      Tecno    2989000    1298000 2476750.000
# 9       Vivo    5730000     519000 3201925.520
# 10    Xiaomi    4599000    1032069 2459427.375
# 11  berjemur    1075000    1075000 1075000.000
# 12      itel    1299000    1098900 1211725.000

# %%
fig, ax1 = plt.subplots(figsize=(10, 10))
plt.ticklabel_format(style='plain', axis='y')
plt.grid()
tidy = all_price.melt(id_vars='Brand').rename(columns=str.title)
sns.barplot(x='Brand', y='Value', hue='Variable', data=tidy, ax=ax1)
plt.title('Price per Brand')
sns.despine(fig)

# %%
all_price_mean = all_price[['Price_max','Price_min','Price_avg']].mean()
all_price_mean
# Out:
# Price_max   3386731.308
# Price_min   1374190.462
# Price_avg   2254000.408
# dtype: float64

# %%
avg_all_price = {'Variable': ['AVG High Price', 'AVG Low Price', 'AVG Standart Price'],
            'Value': all_price_mean}
dt_vis_data = pd.DataFrame(avg_all_price)

# membuat bar plot
plt.ticklabel_format(style='plain', axis='y')
plt.bar(dt_vis_data['Variable'], dt_vis_data['Value'])
plt.ylabel('Price')
plt.title('Maximum, Minimum, and Average Prices')
plt.show()
