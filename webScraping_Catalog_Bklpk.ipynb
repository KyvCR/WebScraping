# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests

# %%
#get URL
url = ('https://www.bukalapak.com/c')
response = requests.get(url)
#print(response)

#check content
soup = bs(response.content, 'html.parser')

# %%
catagories = soup.find('div',{'id' : 'categories'})

#get catagory product
header = []
for h3 in catagories.find_all('h3'):
  header.append(h3.text.strip())
header
# Out:
# ['Elektronik',
#  'Evoucher',
#  'Fashion Anak',
#  'Fashion Pria',
#  'Fashion Wanita',
#  'Food',
#  'Games',
#  'Handphone',
#  'Hobi & Koleksi',
#  'Industrial',
#  'ItemX',
#  'Kamera',
#  'Kesehatan',
#  'Komputer',
#  'Logam Mulia',
#  'Luxury',
#  'Media',
#  'Mobil, Part dan Aksesoris',
#  'Motor',
#  'Olahraga',
#  'Perawatan & Kecantikan',
#  'Perawatan Rumah Tangga',
#  'Perlengkapan Bayi',
#  'Perlengkapan Kantor',
#  'Rumah Tangga',
#  'Sepeda',
#  'Sparca Industrial',
#  'Sparca Motor',
#  'Tiket & Voucher',
#  'Vape']

# %%
#get sub_catagory from catagory
catagory =[]
for all in catagories.find_all('div',{'class':'bl-flex-item masonry-item ut-category-item'}):
  x = []
  for h3 in all.find('h3'):
    x.append(h3.text.strip())
    list = []
    for a in all.find_all('a',{'class' : 'category-list ut-category-subcategory'}):
      list.append(a.text.strip())
    x.append(list)
  catagory.append(x)
catagory
# Out:
# [['Elektronik',
#   ['Walkie Talkie',
#    'Media Player & Set Top Box',
#    'Komponen Elektronik',
#    'Aksesoris TV & Video',
#    'Voice Recorder',
#    'Elektronik Dapur',
#    'Humidifier & Dehumidifier',
#    'Air Purifier',
#    'Elektronik Audio',
#    'Televisi',
#    'CD, VCD, DVD, Blu-Ray Player',
#    'Home Theater',
#    'Portable Audio Player',
#    'Proyektor',
#    'Radio & Tape',
#    'Baterai',
#    'GPS',
#    'Elektronik Lainnya',
#    'Mesin Jahit',
#    'Kulkas & Showcase',
#    'AC',
#    'Mesin Cuci',
#    'Dispenser',
#    'Vacuum Cleaner',
#    'Setrika & Steamer',
#    'Stop Kontak',
#    'Kipas Angin',
#    'Lampu & Alat Penerangan',
#    'Telepon',
#    'Grosir Elektronik']],
#  ['Evoucher',
#   ['Voucher Makanan',
#    'Voucher Hotel & Travel',
#    'Aplikasi Hiburan',
#    'Streaming Voucher',
#    'Voucher Belanja',
#    'Jasa & Layanan',
#    'Software & Aplikasi',
#    'Kode Voucher',
#    'Pulsa & Paket Data']],
#  ['Fashion Anak',
#   ['Couple',
#    'Anak Laki-laki',
#    'Anak Perempuan',
#    'Anak (Unisex)',
#    'Busana Muslim',
#    'Grosir Fashion Anak']],
#  ['Fashion Pria',
#   ['Jam Tangan',
#    'Sepatu',
#    'Kacamata',
#    'Topi',
#    'Kaos',
#    'Polo Shirt',
#    'Kemeja',
#    'Jas',
#    'Sweater',
#    'Jaket',
#    'Pakaian Dalam',
#    'Tas Pria',
#    'Jeans',
#    'Celana',
#    'Sandal',
#    'Dompet',
#    'Piyama/Baju Tidur',
#    'Sarung Tangan',
#    'Ikat Pinggang',
#    'Perhiasan & Aksesoris',
#    'Kaus Kaki',
#    'Baju Muslim & Perlengkapan Sholat',
#    'Bahan & Kain',
#    'Grosir Fashion Pria']],
#  ['Fashion Wanita',
#   ['Sandal',
#    'Tas Wanita',
#    'Jilbab',
#    'Jam Tangan',
#    'Perhiasan & Aksesoris',
#    'Baju Muslim & Perlengkapan Sholat',
#    'Kacamata',
#    'Topi',
#    'Kaos',
#    'Polo Shirt',
#    'Kemeja, Blouse',
#    'Dress',
#    'Sweater',
#    'Jaket',
#    'Bolero, Cardigan',
#    'Kebaya',
#    'Rok',
#    'Legging & Stocking',
#    'Baju Hamil',
#    'Bikini',
#    'Pakaian Dalam, Lingerie',
#    'Jeans',
#    'Celana',
#    'Sepatu',
#    'Sendal',
#    'Dompet',
#    'Sarung Tangan',
#    'Ikat Pinggang',
#    'Kaus Kaki',
#    'Piyama/Baju Tidur',
#    'Jumpsuit',
#    'Bahan & Kain',
#    'Grosir Fashion Wanita']],
#  ['Food',
#   ['Makanan',
#    'Minuman',
#    'Cemilan / Snack',
#    'Dairy Products',
#    'Bumbu',
#    'Bahan Mentah',
#    'Merchant',
#    'Makanan Jadi',
#    'Beras',
#    'Makanan Kaleng',
#    'Makanan Beku',
#    'Mie & Pasta',
#    'Grosir Food',
#    'Telur & Protein',
#    'Bahan Kue',
#    'Makanan Sarapan',
#    'Makanan Kering',
#    'Kopi',
#    'Kue',
#    'Paket & Parsel Makanan',
#    'Sayur & Buah',
#    'Tepung',
#    'Teh']],
#  ['Games',
#   ['Free Fire',
#    'Mobile Legends',
#    'PUBG',
#    'Valorant',
#    'Growtopia',
#    'Higgs Domino',
#    'AOV',
#    'Games Lainnya',
#    'Genshin Impact',
#    'Ragnarok',
#    'Steam Wallet',
#    'Playstation Network',
#    'Call of Duty',
#    'Sausage Man',
#    'Point Blank',
#    'Roblox',
#    'Garena Shell',
#    'Dragon Raja',
#    'UniPin Voucher',
#    'LifeAfter',
#    'Lords Mobile',
#    'Chess Rush',
#    'Hago',
#    'Dota 2',
#    'Honkai Impact 3',
#    'PC Games']],
#  ['Handphone',
#   ['HP & Smartphone',
#    'Wearable Devices',
#    'Tablet',
#    'Power Bank',
#    'Headset (Earphone)',
#    'Aksesoris Handphone',
#    'Memory Card',
#    'Spare Part & Tools Handphone',
#    'Kartu Perdana',
#    'Grosir Handphone']],
#  ['Hobi & Koleksi',
#   ['Batu Cincin',
#    'Produk Dewasa',
#    'Buku',
#    'Video Game',
#    'Mainan',
#    'Musik',
#    'Koleksi',
#    'Berkebun',
#    'Pet Food & Stuff',
#    'Console',
#    'Grosir Hobi & Koleksi',
#    'Ikan Cupang & Guppy']],
#  ['Industrial',
#   ['Tools',
#    'Mesin',
#    'Safety',
#    'Peralatan Medis-Laboratori',
#    'Industrial Lainnya',
#    'Perkakas Rumah Tangga',
#    'Grosir Industrial']],
#  ['ItemX',
#   ['Trading Cards', 'Vehicle Models', 'Figures', 'Tickets', 'Hobbies']],
#  ['Kamera',
#   ['Action Camera',
#    'Drone',
#    'Kamera Digital',
#    'Handycam',
#    'Kamera Analog',
#    'CCTV',
#    'Spy Cam',
#    'Lensa',
#    'Flash',
#    'Baterai',
#    'Filter',
#    'Hood & Cap',
#    'Charger',
#    'Memory Card',
#    'Monopod, Tripod, & Rig',
#    'Converter & Adapter',
#    'Remote & Trigger',
#    'Tas & Case',
#    'Strap',
#    'Perlengkapan Studio',
#    'Aksesoris Kamera',
#    'Sparepart Kamera',
#    'Gimbal & Stabilizer',
#    'Grosir Kamera']],
#  ['Kesehatan',
#   ['Kesehatan Wanita',
#    'Masker',
#    'Obat & Vitamin',
#    'Kesehatan Mulut & Gigi',
#    'Kesehatan Mata',
#    'Kesehatan Telinga',
#    'Alat Kesehatan',
#    'Tulang, Otot & Sendi',
#    'Essential Oil',
#    'Produk Kesehatan Lainnya',
#    'Grosir Kesehatan']],
#  ['Komputer',
#   ['Hardware',
#    'Gaming',
#    'Aksesoris',
#    'Desktop',
#    'Laptop',
#    'Server',
#    'Printer & Scanner',
#    'Software Original',
#    'Scanner',
#    'Monitor',
#    'Mini PC',
#    'Grosir Komputer']],
#  ['Logam Mulia',
#   ['Emas', 'Voucher Emas', 'Gift Logam Mulia', 'Perhiasan Emas']],
#  ['Luxury', ['Male', 'Female', 'Unisex']],
#  ['Media', ['Ebook', 'Foto', 'Musik', 'Video']],
#  ['Mobil, Part dan Aksesoris',
#   ['Mobil',
#    'Aksesoris Mobil',
#    'Audio Mobil',
#    'Exhaust System Mobil',
#    'Eksterior Mobil',
#    'Interior Mobil',
#    'Kaki-kaki Mobil',
#    'Mesin Mobil',
#    'Produk Perawatan Mobil',
#    'Ban Mobil',
#    'Velg Mobil',
#    'Grosir Mobil, Part dan Aksesories']],
#  ['Motor',
#   ['Motor',
#    'Sparepart Motor',
#    'Aksesoris Motor',
#    'Produk Perawatan Motor',
#    'Outwear Motor',
#    'Grosir Motor']],
#  ['Olahraga',
#   ['Surfing & Diving',
#    'Lari',
#    'Badminton',
#    'Renang',
#    'Pancing',
#    'Tenis',
#    'Tenis Meja',
#    'Sepakbola & Futsal',
#    'Basket',
#    'Golf',
#    'Outdoor',
#    'Hunting',
#    'Exercise & Fitness',
#    'Skateboard',
#    'Roller Skate',
#    'Yoga & Pilates',
#    'Olahraga Lainnya',
#    'Grosir Olahraga',
#    'Suplemen & Vitamin']],
#  ['Perawatan & Kecantikan',
#   ['Perawatan Kaki, Tangan, dan Kuku',
#    'Perawatan Mata',
#    'Perawatan Tubuh',
#    'Perawatan Wajah',
#    'Hair Care',
#    'Makeup',
#    'Alat Kecantikan',
#    'Makeup Bibir',
#    'Makeup Mata',
#    'Makeup Rambut',
#    'Makeup Wajah',
#    'Parfum',
#    'Suplemen Diet',
#    'Produk Kecantikan Lainnya',
#    'Grosir Perawatan & Kecantikan']],
#  ['Perawatan Rumah Tangga',
#   ['Pembersih Pakaian',
#    'Tisu',
#    'Pengharum Ruangan',
#    'Pembersih Lantai',
#    'Pembasmi Hama & Serangga',
#    'Pembersih Dapur',
#    'Pembersih Luar Rumah',
#    'Pembersih Kaca',
#    'Pembersih Kamar Mandi',
#    'Disinfektan',
#    'Pembersih Lainnya']],
#  ['Perlengkapan Bayi',
#   ['Pakaian Bayi',
#    'Perlengkapan Makan',
#    'Perlengkapan Mandi',
#    'Perlengkapan Tidur',
#    'Perawatan Tubuh',
#    'Diapering',
#    'Feeding & Nursing',
#    'Stroller & Walker',
#    'Baby Carrier',
#    'Bouncer & Chair',
#    'Mainan',
#    'Furniture',
#    'Makanan',
#    'Perlengkapan Bayi Lainnya',
#    'Grosir Perlengkapan Bayi']],
#  ['Perlengkapan Kantor',
#   ['Alat Tulis Kantor', 'Alat Kantor', 'Grosir Perlengkapan Kantor']],
#  ['Rumah Tangga',
#   ['Elektronik',
#    'Home Stuff',
#    'Furniture & Interior',
#    'Dapur',
#    'Kamar Tidur',
#    'Kamar Mandi',
#    'Ruang Makan',
#    'Perlengkapan Kebersihan',
#    'Tempat Penyimpanan & Organizer',
#    'Gembok & Kunci Pengaman',
#    'Payung',
#    'Jam',
#    'Travel',
#    'Laundry',
#    'Grosir Rumah Tangga']],
#  ['Sepeda',
#   ['Equipment & Tools',
#    'Outwear',
#    'Fullbike',
#    'Frame',
#    'Fork & Suspension',
#    'Steering',
#    'Brake',
#    'Saddle & Seatpost',
#    'Drivetrain',
#    'Wheel (Hub, Rims, dll)',
#    'Part Generik',
#    'Nutrition & Energy',
#    'Grosir Sepeda']],
#  ['Sparca Industrial', ['Sparca Pilihan']],
#  ['Sparca Motor', ['Jas Hujan Pilihan', 'Helm Pilihan', 'Lampu Pilihan']],
#  ['Tiket & Voucher',
#   ['Makanan & Minuman',
#    'Travel & Hiburan',
#    'Tiket & Voucher Lainnya',
#    'Kartu Uang Elektronik',
#    'Voucher Donasi']],
#  ['Vape', ['Liquid', 'Spareparts', 'Device', 'Merchandise']]]

# %%
#inster into dataframe
df = pd.DataFrame(catagory, columns = ['Catagory', 'List'])
df
# Out:
#                      Catagory  \
# 0                  Elektronik
# 1                    Evoucher
# 2                Fashion Anak
# 3                Fashion Pria
# 4              Fashion Wanita
# 5                        Food
# 6                       Games
# 7                   Handphone
# 8              Hobi & Koleksi
# 9                  Industrial
# 10                      ItemX
# 11                     Kamera
# 12                  Kesehatan
# 13                   Komputer
# 14                Logam Mulia
# 15                     Luxury
# 16                      Media
# 17  Mobil, Part dan Aksesoris
# 18                      Motor
# 19                   Olahraga
# 20     Perawatan & Kecantikan
# 21     Perawatan Rumah Tangga
# 22          Perlengkapan Bayi
# 23        Perlengkapan Kantor
# 24               Rumah Tangga
# 25                     Sepeda
# 26          Sparca Industrial
# 27               Sparca Motor
# 28            Tiket & Voucher
# 29                       Vape
#
#                                                  List
# 0   [Walkie Talkie, Media Player & Set Top Box, Ko...
# 1   [Voucher Makanan, Voucher Hotel & Travel, Apli...
# 2   [Couple, Anak Laki-laki, Anak Perempuan, Anak ...
# 3   [Jam Tangan, Sepatu, Kacamata, Topi, Kaos, Pol...
# 4   [Sandal, Tas Wanita, Jilbab, Jam Tangan, Perhi...
# 5   [Makanan, Minuman, Cemilan / Snack, Dairy Prod...
# 6   [Free Fire, Mobile Legends, PUBG, Valorant, Gr...
# 7   [HP & Smartphone, Wearable Devices, Tablet, Po...
# 8   [Batu Cincin, Produk Dewasa, Buku, Video Game,...
# 9   [Tools, Mesin, Safety, Peralatan Medis-Laborat...
# 10  [Trading Cards, Vehicle Models, Figures, Ticke...
# 11  [Action Camera, Drone, Kamera Digital, Handyca...
# 12  [Kesehatan Wanita, Masker, Obat & Vitamin, Kes...
# 13  [Hardware, Gaming, Aksesoris, Desktop, Laptop,...
# 14  [Emas, Voucher Emas, Gift Logam Mulia, Perhias...
# 15                             [Male, Female, Unisex]
# 16                        [Ebook, Foto, Musik, Video]
# 17  [Mobil, Aksesoris Mobil, Audio Mobil, Exhaust ...
# 18  [Motor, Sparepart Motor, Aksesoris Motor, Prod...
# 19  [Surfing & Diving, Lari, Badminton, Renang, Pa...
# 20  [Perawatan Kaki, Tangan, dan Kuku, Perawatan M...
# 21  [Pembersih Pakaian, Tisu, Pengharum Ruangan, P...
# 22  [Pakaian Bayi, Perlengkapan Makan, Perlengkapa...
# 23  [Alat Tulis Kantor, Alat Kantor, Grosir Perlen...
# 24  [Elektronik, Home Stuff, Furniture & Interior,...
# 25  [Equipment & Tools, Outwear, Fullbike, Frame, ...
# 26                                   [Sparca Pilihan]
# 27   [Jas Hujan Pilihan, Helm Pilihan, Lampu Pilihan]
# 28  [Makanan & Minuman, Travel & Hiburan, Tiket & ...
# 29          [Liquid, Spareparts, Device, Merchandise]

# %%
df.to_csv('Catalog_Produckt_Bukalapak.csv', index=False)
